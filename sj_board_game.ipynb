# %%
#library to use dataframes
import pandas as pd

#library to connect & interact with databases
from sqlalchemy import create_engine, inspect

# %%
#set the database file location to a variable
db_file = r'datasets/boardgames.sqlite'

# set the connection to SQLite database in a variable
engine = create_engine(f"sqlite:///{db_file}")

# %%
#get a list of all the tables in the database
engine.table_names()
# Out:
# ['BoardGames',
#  'bgg.ldaOut.top.documents',
#  'bgg.ldaOut.top.terms',
#  'bgg.ldaOut.topics',
#  'bgg.topics']

# %%
#check if a table exists)
engine.has_table('bgg.topics')
# Out:
# True

# %%
#this is used to look at the schema of elements in a database
inspector = inspect(engine)

# %%
# get the fields (columns) and their attributes for the table called "test"
#this is a list where each item is a field(column)
print(inspector.get_columns('BoardGames'))
# Out:
# [{'name': 'row_names', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'game.id', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'game.type', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.description', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.image', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.maxplayers', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.maxplaytime', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.minage', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.minplayers', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.minplaytime', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.name', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.playingtime', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.thumbnail', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.yearpublished', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgameartist', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamecategory', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamecompilation', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamedesigner', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgameexpansion', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamefamily', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgameimplementation', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgameintegration', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamemechanic', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamepublisher', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.total', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.average', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.averageweight', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.bayesaverage', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.family.abstracts.bayesaverage', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.family.abstracts.pos', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.family.cgs.bayesaverage', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement ...

# %%
#set the table column information to a variable
fields = inspector.get_columns('BoardGames')

# %%
#put the information into a dataframe for readability
field_names = pd.DataFrame.from_dict(fields)
field_names
# Out:
#    autoincrement default                                   name  nullable  \
# 0           auto    None                              row_names      True
# 1           auto    None                                game.id      True
# 2           auto    None                              game.type      True
# 3           auto    None                    details.description      True
# 4           auto    None                          details.image      True
# 5           auto    None                     details.maxplayers      True
# 6           auto    None                    details.maxplaytime      True
# 7           auto    None                         details.minage      True
# 8           auto    None                     details.minplayers      True
# 9           auto    None                    details.minplaytime      True
# 10          auto    None                           details.name      True
# 11          auto    None                    details.playingtime      True
# 12          auto    None                      details.thumbnail      True
# 13          auto    None                  details.yearpublished      True
# 14          auto    None             attributes.boardgameartist      True
# 15          auto    None           attributes.boardgamecategory      True
# 16          auto    None        attributes.boardgamecompilation      True
# 17          auto    None           attributes.boardgamedesigner      True
# 18          auto    None          attributes.boardgameexpansion      True
# 19          auto    None             attributes.boardgamefamily      True
# 20          auto    None     attributes.boardgameimplementation      True
# 21          auto    None        attributes.boardgameintegration      True
# 22          auto    None           attributes.boardgamemechanic      True
# 23          auto    None          attributes.boardgamepublisher      True
# 24          auto    None                       attributes.total      True
# 25          auto    None                          stats.average      True
# 26          auto    None                    stats.averageweight      True
# 27          auto    None                     stats.bayesaverage      True
# 28          auto    None    stats.family.abstracts.bayesaverage      True
# 29          auto    None             stats.family.abstracts.pos      True
# ..           ...     ...                                    ...       ...
# 51          auto    None                          stats.trading      True
# 52          auto    None                       stats.usersrated      True
# 53          auto    None                          stats.wanting      True
# 54          auto    None                          stats.wishing      True
# 55          auto    None              polls.language_dependence      True
# 56          auto    None           polls.suggested_numplayers.1      True
# 57          auto    None          polls.suggested_numplayers.10      True
# 58          auto    None           polls.suggested_numplayers.2      True
# 59          auto    None           polls.suggested_numplayers.3      True
# 60          auto    None           polls.suggested_numplayers.4      True
# 61          auto    None           polls.suggested_numplayers.5      True
# 62          auto    None           polls.suggested_numplayers.6      True
# 63          auto    None           polls.suggested_numplayers.7      True
# 64          auto    None           polls.suggested_numplayers.8      True
# 65          auto    None           polls.suggested_numplayers.9      True
# 66          auto    None        polls.suggested_numplayers.Over      True
# 67          auto    None              polls.suggested_playerage      True
# 68          auto    None        attributes.t.links.concat.2....      True
# 69          auto    None        stats.family.amiga.bayesaverage      True
# 70          auto    None                 stats.family.amiga.pos      True
# 71          auto    None       stats.family.arcade.bayesaverage      True
# 72          auto    None                stats.family.arcade.pos      True
# 73          auto    None      stats.family.atarist.bayesaverage      True
# 74          auto    None               stats.family.atarist.pos      True
# 75          auto    None  stats.family.commodore64.bayesaverage      True
# 76          auto    None           stats.family.commodore64.pos      True
# 77          auto    None     stats.subtype.rpgitem.bayesaverage      True
# 78          auto    None              stats.subtype.rpgitem.pos      True
# 79          auto    None   stats.subtype.videogame.bayesaverage      True
# 80          auto    None            stats.subtype.videogame.pos      True
#
#     primary_key     type
# 0             0     TEXT
# 1             0     TEXT
# 2             0     TEXT
# 3             0     TEXT
# 4             0     TEXT
# 5             0  INTEGER
# 6             0  INTEGER
# 7             0  INTEGER
# 8             0  INTEGER
# 9             0  INTEGER
# 10            0     TEXT
# 11            0  INTEGER
# 12            0     TEXT
# 13            0  INTEGER
# 14            0     TEXT
# 15            0     TEXT
# 16            0     TEXT
# 17            0     TEXT
# 18            0     TEXT
# 19            0     TEXT
# 20            0     TEXT
# 21            0     TEXT
# 22            0     TEXT
# 23            0     TEXT
# 24            0     REAL
# 25            0     REAL
# 26            0     REAL
# 27            0     REAL
# 28            0     REAL
# 29            0     REAL
# ..          ...      ...
# 51            0     REAL
# 52            0     REAL
# 53            0     REAL
# 54            0     REAL
# 55            0     TEXT
# 56            0     TEXT
# 57            0     TEXT
# 58            0     TEXT
# 59            0     TEXT
# 60            0     TEXT
# 61            0     TEXT
# 62            0     TEXT
# 63            0     TEXT
# 64            0     TEXT
# 65            0     TEXT
# 66            0     TEXT
# 67            0     TEXT
# 68            0     TEXT
# 69            0     REAL
# 70            0     REAL
# 71            0     REAL
# 72            0     REAL
# 73            0     REAL
# 74            0     REAL
# 75            0     REAL
# 76            0     REAL
# 77            0     REAL
# 78            0     REAL
# 79            0     REAL
# 80            0     REAL
#
# [81 rows x 6 columns]

# %%
#check if a 'bgg.ldaOut.top.documents', exists 
engine.has_table('bgg.ldaOut.top.documents')
# Out:
# True

# %%
# get the fields (columns) and their attributes for the table called "test"
#this is a list where each item is a field(column)
print(inspector.get_columns('bgg.ldaOut.top.documents'))
# Out:
# [{'name': 'row_names', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'document', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'topic', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'gamma', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}]

# %%
#set the table column information to a variable
fields = inspector.get_columns('bgg.ldaOut.top.documents')
#put the information into a dataframe for readability
field_names = pd.DataFrame.from_dict(fields)
field_names
# Out:
#   autoincrement default       name  nullable  primary_key     type
# 0          auto    None  row_names      True            0     TEXT
# 1          auto    None   document      True            0     TEXT
# 2          auto    None      topic      True            0  INTEGER
# 3          auto    None      gamma      True            0     REAL

# %%
field_names.shape
# Out:
# (4, 6)

# %%
rows = print(field_names.shape[0])
# Out:
# 4

# %%
cols = print(field_names.shape[1])
# Out:
# 6

# %%
print(f"Table has {field_names.shape[0]} rows and {field_names.shape[1]} clolumns")
# Out:
# Table has 4 rows and 6 clolumns

# %%
sql = "select * from BoardGames;"
topdoc_df = pd.read_sql(sql, engine)
topdoc_df.shape
print(f"Table has {field_names.shape[0]} rows and {field_names.shape[1]} clolumns")
# Out:
# Table has 0 rows and 0 clolumns

# %%
sql = "select * from 'bgg.ldaOut.top.terms'"
topdoc_df = pd.read_sql(sql, engine)
topdoc_df.shape
print(f"Table has {topdoc_df.shape[0]} rows and {topdoc_df.shape[1]} clolumns")
# Out:
# Table has 250 rows and 4 clolumns

# %%
sql = "select * from 'bgg.topics'"
topdoc_df = pd.read_sql(sql, engine)
topdoc_df.shape
print(f"Table has {topdoc_df.shape[0]} rows and {topdoc_df.shape[1]} clolumns")
# Out:
# Table has 29313 rows and 74 clolumns

# %%
sql = "select * from 'bgg.ldaOut.topics'"
topdoc_df = pd.read_sql(sql, engine)
topdoc_df.shape
print(f"Table has {topdoc_df.shape[0]} rows and {topdoc_df.shape[1]} clolumns")
# Out:
# Table has 29229 rows and 2 clolumns

# %%
#Read each table in database
for name in engine.table_names():
    i = 0
    fields[i] = inspector.get_columns('name')
    i += 1
    print(name)
# Out:
# BoardGames
# bgg.ldaOut.top.documents
# bgg.ldaOut.top.terms
# bgg.ldaOut.topics
# bgg.topics

# %%
#Read each table in database
fields = {}
for name in engine.table_names():
    i = 0
    fields[i] = inspector.get_columns('name')
    i += 1
    print(name)
# Out:
# BoardGames
# bgg.ldaOut.top.documents
# bgg.ldaOut.top.terms
# bgg.ldaOut.topics
# bgg.topics

# %%
#Read each table in database
for name in engine.table_names():
    i = 0
    n = inspector.get_columns('name')
    i += 1
    print(name)
    sql = "select * from 'name'"
    topdoc_df = pd.read_sql(sql, engine)
    topdoc_df.shape
    print(f"Table has {topdoc_df[0]} rows and {topdoc_df[1]} clolumns")
# Out:
# BoardGames
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     551     def do_execute(self, cursor, statement, parameters, context=None):
# --> 552         cursor.execute(statement, parameters)
#     553
#
# OperationalError: no such table: name
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-55-8342a50960e0> in <module>
#       6     print(name)
#       7     sql = "select * from 'name'"
# ----> 8     topdoc_df = pd.read_sql(sql, engine)
#       9     topdoc_df.shape
#      10     print(f"Table has {topdoc_df[0]} rows and {topdoc_df[1]} clolumns")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     395             sql, index_col=index_col, params=params,
#     396             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 397             chunksize=chunksize)
#     398
#     399
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1097         args = _convert_params(sql, params)
#    1098
# -> 1099         result = self.execute(*args)
#    1100         columns = result.keys()
#    1101
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#     988     def execute(self, *args, **kwargs):
#     989         """Simple passthrough to SQLAlchemy connectable"""
# --> 990         return self.connectable.execute(*args, **kwargs)
#     991
#     992     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2164
#    2165         connection = self._contextual_connect(close_with_result=True)
# -> 2166         return connection.execute(statement, *multiparams, **params)
#    2167
#    2168     def scalar(self, statement, *multiparams, **params):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     980         """
#     981         if isinstance(object_, util.string_types[0]):
# --> 982             return self._execute_text(object_, multiparams, params)
#     983         try:
#     984             meth = object_._execute_on_connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1153             parameters,
#    1154             statement,
# -> 1155             parameters,
#    1156         )
#    1157         if self._has_events or self.engine._has_events:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1242                 if not evt_handled:
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#    1246         except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     550
#     551     def do_execute(self, cursor, statement, parameters, context=None):
# --> 552         cursor.execute(statement, parameters)
#     553
#     554     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: name
# [SQL: select * from 'name']
# (Background on this error at: http://sqlalche.me/e/e3q8)
